# %% [markdown]
# <a href="https://colab.research.google.com/github/djohan-coder/Data-Car_sales/blob/main/Car_sales%20data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### DATA PREPARATION

# %% [markdown]
# >

# %% [markdown]
# **Persiapan File**

# %% [markdown]
# **Upload Manual secara mudah**

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# >

# %% [markdown]
# ### **STEP 1**

# %% [markdown]
# **Import Library**

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# **Penjelasan**
# >
# - Pandas: Library utama untuk memanipulasi data
# - Numpy: Library untuk operasi numerik
# - Matplotlib & Seaborn: Library untuk visualisasi
# - Warning.filterwarnings('Ignore'): Sembunyikan warning yang tidak penting

# %% [markdown]
# >

# %% [markdown]
# ### **STEP 2**

# %% [markdown]
# **Import Data Csv**

# %%
# Load data
df = pd.read_csv('/content/drive/MyDrive/Car_sales.csv')

# %%
# Lihat berapa baris dan kolom
print(f"jumlah baris: {df.shape[0]}")
print(f"jumlah kolom: {df.shape[1]}")
# Out:
# jumlah baris: 157
# jumlah kolom: 16

# %% [markdown]
# **Penjelasan**
# >
# - pd.read_csv(): Membaca file CSV dan mengkonversi ke DataFrame
# - df.Shape: Menampilkan dimensi data (baris, kolom)

# %% [markdown]
# >

# %% [markdown]
# ### **STEP 3**

# %% [markdown]
# **Lihat sample data**

# %%
# 5 baris pertama
print(df.head())
# Out:
#   Manufacturer    Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 0        Acura  Integra              16.919               16.360    Passenger
# 1        Acura       TL              39.384               19.875    Passenger
# 2        Acura       CL              14.114               18.225    Passenger
# 3        Acura       RL               8.588               29.725    Passenger
# 4         Audi       A4              20.397               22.255    Passenger
#
#    Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 0               21.50          1.8       140.0      101.2   67.3   172.4
# 1               28.40          3.2       225.0      108.1   70.3   192.9
# 2                 NaN          3.2       225.0      106.9   70.6   192.0
# 3               42.00          3.5       210.0      114.6   71.4   196.6
# 4               23.99          1.8       150.0      102.6   68.2   178.0
#
# ...

# %%
# 5 baris terakhir
print(df.tail())
# Out:
#     Manufacturer Model  Sales_in_thousands  __year_resale_value Vehicle_type  \
# 152        Volvo   V40               3.545                  NaN    Passenger
# 153        Volvo   S70              15.245                  NaN    Passenger
# 154        Volvo   V70              17.531                  NaN    Passenger
# 155        Volvo   C70               3.493                  NaN    Passenger
# 156        Volvo   S80              18.969                  NaN    Passenger
#
#      Price_in_thousands  Engine_size  Horsepower  Wheelbase  Width  Length  \
# 152                24.4          1.9       160.0      100.5   67.6   176.6
# 153                27.5          2.4       168.0      104.9   69.3   185.9
# 154                28.8          2.4       168.0      104.9   69.3   186.2
# 155                45.5          2.3       236.0      104.9   71.5   185.7
# 156                36.0          2.9       201.0      109.9   72.1   189.8
#
# ...

# %%
# baris random
print(df.sample(5))
# Out:
#     Manufacturer     Model  Sales_in_thousands  __year_resale_value  \
# 2          Acura        CL              14.114               18.225
# 128         Saab     3-Sep              12.115                  NaN
# 134       Subaru   Outback              47.107                  NaN
# 91       Mercury  Villager              20.380               14.795
# 83    Mitsubishi    3000GT               0.110               20.940
#
#     Vehicle_type  Price_in_thousands  Engine_size  Horsepower  Wheelbase  \
# 2      Passenger                 NaN          3.2       225.0      106.9
# 128    Passenger              26.100          2.0       185.0      102.6
# 134    Passenger              22.695          2.5       165.0      103.5
# 91           Car              22.510          3.3       170.0      112.2
# 83     Passenger              25.450          3.0       161.0       97.2
#
#      Width  Length  Curb_weight  Fuel_capacity  Fuel_efficiency Latest_Launch  \
# ...

# %% [markdown]
# >

# %% [markdown]
# **Informasi Kolom**

# %%
# Info lengkap
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 157 entries, 0 to 156
# Data columns (total 16 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Manufacturer         157 non-null    object
#  1   Model                157 non-null    object
#  2   Sales_in_thousands   157 non-null    float64
#  3   __year_resale_value  121 non-null    float64
#  4   Vehicle_type         157 non-null    object
#  5   Price_in_thousands   155 non-null    float64
#  6   Engine_size          156 non-null    float64
#  7   Horsepower           156 non-null    float64
#  8   Wheelbase            156 non-null    float64
#  9   Width                156 non-null    float64
#  10  Length               156 non-null    float64
#  11  Curb_weight          155 non-null    float64
#  12  Fuel_capacity        156 non-null    float64
#  13  Fuel_efficiency      154 non-null    float64
#  14  Latest_Launch        157 non-null    object
# ...

# %%
# Nama semua kolom
print(df.columns.tolist())
# Out:
# ['Manufacturer', 'Model', 'Sales_in_thousands', '__year_resale_value', 'Vehicle_type', 'Price_in_thousands', 'Engine_size', 'Horsepower', 'Wheelbase', 'Width', 'Length', 'Curb_weight', 'Fuel_capacity', 'Fuel_efficiency', 'Latest_Launch', 'Power_perf_factor']

# %%
# Tipe data setiap kolom
print(df.dtypes)
# Out:
# Manufacturer            object
# Model                   object
# Sales_in_thousands     float64
# __year_resale_value    float64
# Vehicle_type            object
# Price_in_thousands     float64
# Engine_size            float64
# Horsepower             float64
# Wheelbase              float64
# Width                  float64
# Length                 float64
# Curb_weight            float64
# Fuel_capacity          float64
# Fuel_efficiency        float64
# Latest_Launch           object
# Power_perf_factor      float64
# dtype: object

# %% [markdown]
# >

# %% [markdown]
# **Statistika Deskriptif**

# %%
# Statistika deskriptif kolom numerik
print(df.describe())
# Out:
#        Sales_in_thousands  __year_resale_value  Price_in_thousands  \
# count          157.000000           121.000000          155.000000
# mean            52.998076            18.072975           27.390755
# std             68.029422            11.453384           14.351653
# min              0.110000             5.160000            9.235000
# 25%             14.114000            11.260000           18.017500
# 50%             29.450000            14.180000           22.799000
# 75%             67.956000            19.875000           31.947500
# max            540.561000            67.550000           85.500000
#
#        Engine_size  Horsepower   Wheelbase       Width      Length  \
# count   156.000000  156.000000  156.000000  156.000000  156.000000
# mean      3.060897  185.948718  107.487179   71.150000  187.343590
# std       1.044653   56.700321    7.641303    3.451872   13.431754
# min       1.000000   55.000000   92.600000   62.600000  149.400000
# ...

# %%
# Statistika untuk kolom ketegorik
print(df.describe(include='object'))
# Out:
#        Manufacturer Model Vehicle_type Latest_Launch
# count           157   157          157           157
# unique           30   156            2           130
# top            Ford  Neon    Passenger     1/29/2012
# freq             11     2          116             2

# %% [markdown]
# **Penjelasan**
# >
# - Count: jumlah data non-null
# - mean: rata-rata
# - std: standar deviasi
# - min/max: nilai minimum/maksimum
# - 25%/50%/75%: persentil/kuartil

# %% [markdown]
# >

# %% [markdown]
# ### **STEP 4**

# %% [markdown]
# **Hitung Missing Value**

# %%
# jumlah missing value per kolom
missing_count = df.isnull().sum()
print(missing_count[missing_count > 0])
# Out:
# __year_resale_value    36
# Price_in_thousands      2
# Engine_size             1
# Horsepower              1
# Wheelbase               1
# Width                   1
# Length                  1
# Curb_weight             2
# Fuel_capacity           1
# Fuel_efficiency         3
# Power_perf_factor       2
# dtype: int64

# %%
# Presentase Missing
missing_pct = (df.isnull().sum() / len(df)) * 100
print(missing_pct[missing_pct > 0].sort_values(ascending=False))
# Out:
# __year_resale_value    22.929936
# Fuel_efficiency         1.910828
# Price_in_thousands      1.273885
# Power_perf_factor       1.273885
# Curb_weight             1.273885
# Engine_size             0.636943
# Horsepower              0.636943
# Length                  0.636943
# Width                   0.636943
# Wheelbase               0.636943
# Fuel_capacity           0.636943
# dtype: float64

# %% [markdown]
# >

# %% [markdown]
# **Visualisasi Missing Values**

# %%
import missingno as msno

# %%
# Headmap missing values (opsional, perlu install: pip install missingno)
msno.matrix(df)
plt.show()

# %% [markdown]
# **Penjelasan**
# >
# 1. Tujuan Visualisasi
# - Grafik ini digunakan untuk melihat **nilai yang hilang (missing values/null values)** dalam sebuah dataset. Ini sangat berguna bagi Data Scientist atau Analisis Data untuk memeriksa kualitas data sebelum melakukan analisis lebih lanjut.
# >
# 2. Komponen Grafik
# - **Sumbu X (Atas):** Menampilkan nama-nama kolom (variabel) dalam dataset. Berdasarkan namanya (Manufactur, Model, Horsepower, Fuel_efficiency, dll), dataset ini tampaknya berisi data tentang **mobil atau kendaraan**.
# - **Sumbu Y (Kiri):** Menampilkan jumlah baris data. Angka "1" di atas dan "157" di bawah menunjukkan bahwa dataset ini memiliki 157 baris entri data.
# - **Warna Visualisasi**
#   - **Warna abu- abu Gelap: Menunjukan bahwa data ada (lengkap)**.
#   - **Garis Putih: Menunjukan bahwa data **hilang** (kosong/null/NaN)**.
# >
# 3. Grafik di Sisi Kanan (Sparkline)
# - Di sebelah kanan paling ujung, terdapat grafik garis kecil (sparkline).
# >
#   - Grafik ini menunjukkan kelengkapan data untuk setiap baris secara individual.
#   - Angka **6 dan 16** yang ditunjuk oleh panah kemungkinan besar merujuk pada nomor baris yang memiliki kelengkapan data paling rendah (paling banyak data yang hilang dibandingkan baris lain).

# %% [markdown]
# >

# %% [markdown]
# ### **STEP 5**

# %% [markdown]
# **Handling Missing Values**
# > Strategi Mengisi Missing Values:
# >
# - Tipe Data | Metode | Kapan digunakan
# >
# - Numerik   | Median | Data memiliki outlier
# - Numerik   | Mean   | Data terdistribusi normal
# - Kategorik | Modus  | Ambil nilai paling sering
# - Kategorik |'Unknown'| Jika tidak ada modus jelas

# %% [markdown]
# >

# %% [markdown]
# **Isi Missing Values - NUMERIK**

# %%
# buat copy data
df_clean = df.copy()

# %%
# pilih kolom numerik
numeric_cols = df_clean.select_dtypes(include=[np.number]).columns

# %%
# Isi dengan MEDIAN
for col in numeric_cols:
  if df_clean[col].isnull().sum() > 0:
      median_value = df_clean[col].median()
      df_clean[col].fillna(median_value, inplace=True)
      print(f"{col}: diisi dengan median = {median_value:.2f}")
# Out:
# Price_in_thousands: diisi dengan median = 22.80
# Engine_size: diisi dengan median = 3.00
# Horsepower: diisi dengan median = 177.50
# Wheelbase: diisi dengan median = 107.00
# Width: diisi dengan median = 70.55
# Length: diisi dengan median = 187.90
# Curb_weight: diisi dengan median = 3.34
# Fuel_capacity: diisi dengan median = 17.20
# Fuel_efficiency: diisi dengan median = 24.00
# Power_perf_factor: diisi dengan median = 72.03

# %% [markdown]
# >

# %% [markdown]
# **Kenapa MEDIAN ?**
# >
# - Median tidak terpengaruh outlier
# - Lebih aman untuk dengan distribusi skew
# - Mean bisa bias jika ada nilai ekstrem

# %% [markdown]
# **Isi Missing Values -  KATEGORIK**

# %%
# Pilih kolom kategorik
categorical_cols = df_clean.select_dtypes(include=['object']).columns

# %%
# Isi dengan MODUS
for col in categorical_cols:
  if  df_clean[col].isnull().sum() > 0:
    mode_value = df_clean[col].mode()[0] if not df_clean[col].mode().empty else 'Unknown'
    df_clean[col].fillna(mode_value, inplace=True)
    print(f"{col}: diisi dengan modus = {mode_value}")
